# %%
from autoscraper import AutoScraper

# %%
url="https://www.imdb.com/search/title/?countries=us&title_type=feature&num_votes=10000,&sort=user_rating,desc"
wanted_list=["The Shawshank Redemption","1994","Frank Darabont","Drama","9.3","$28.34M"]

# %%
scraper=AutoScraper()
res=scraper.build(url,wanted_list)

# %%
res
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Lord of the Rings: The Return of the King',
#  "Schindler's List",
#  'The Godfather Part II',
#  '12 Angry Men',
#  'Pulp Fiction',
#  'Kill Bill: The Whole Bloody Affair',
#  'Inception',
#  'The Lord of the Rings: The Two Towers',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'The Matrix',
#  'Goodfellas',
#  'The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Interstellar',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'Se7en',
#  'Terminator 2: Judgment Day',
#  'The Silence of the Lambs',
#  'Star Wars',
#  "It's a Wonderful Life",
#  'Whiplash',
#  'The Prestige',
#  'The Departed',
#  'Gladiator',
#  'American History X',
#  'The Usual Suspects',
#  'Léon',
#  'The Lion King',
#  'Back to the Future',
#  'Apocalypse Now',
#  'Alien',
#  'Once Upon a Time in the West',
#  'Psycho',
#  'Rear Window',
#  'Casablanca',
# ...

# %%
scraper.get_result_similar(url,grouped=True)
# Out:
# {'rule_ggm7': ['The Shawshank Redemption',
#   'The Godfather',
#   'The Dark Knight',
#   'The Lord of the Rings: The Return of the King',
#   "Schindler's List",
#   'The Godfather Part II',
#   '12 Angry Men',
#   'Pulp Fiction',
#   'Kill Bill: The Whole Bloody Affair',
#   'Inception',
#   'The Lord of the Rings: The Two Towers',
#   'Fight Club',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Forrest Gump',
#   'The Matrix',
#   'Goodfellas',
#   'The Empire Strikes Back',
#   "One Flew Over the Cuckoo's Nest",
#   'Interstellar',
#   'Saving Private Ryan',
#   'The Green Mile',
#   'Se7en',
#   'Terminator 2: Judgment Day',
#   'The Silence of the Lambs',
#   'Star Wars',
#   "It's a Wonderful Life",
#   'Whiplash',
#   'The Prestige',
#   'The Departed',
#   'Gladiator',
#   'American History X',
#   'The Usual Suspects',
#   'Léon',
#   'The Lion King',
#   'Back to the Future',
#   'Apocalypse Now',
#   'Alien',
#   'Once Upon a Time in the West',
# ...

# %%
scraper.set_rule_aliases({'rule_ggm7':'Title','rule_y8ti':'Director','rule_0nsk':'Genre','rule_e8a2':'Rating','rule_5tit':'Gross'})

# %%
cat=scraper.get_result_similar(url,group_by_alias=True)

# %%
cat['Director']
# Out:
# ['Frank Darabont',
#  'Francis Ford Coppola',
#  'Christopher Nolan',
#  'Peter Jackson',
#  'Steven Spielberg',
#  'Francis Ford Coppola',
#  'Sidney Lumet',
#  'Quentin Tarantino',
#  'Quentin Tarantino',
#  'Christopher Nolan',
#  'Peter Jackson',
#  'David Fincher',
#  'Peter Jackson',
#  'Robert Zemeckis',
#  'Lana Wachowski',
#  'Martin Scorsese',
#  'Irvin Kershner',
#  'Milos Forman',
#  'Christopher Nolan',
#  'Steven Spielberg',
#  'Frank Darabont',
#  'David Fincher',
#  'James Cameron',
#  'Jonathan Demme',
#  'George Lucas',
#  'Frank Capra',
#  'Damien Chazelle',
#  'Christopher Nolan',
#  'Martin Scorsese',
#  'Ridley Scott',
#  'Tony Kaye',
#  'Bryan Singer',
#  'Luc Besson',
#  'Roger Allers',
#  'Robert Zemeckis',
#  'Francis Ford Coppola',
#  'Ridley Scott',
#  'Sergio Leone',
#  'Alfred Hitchcock',
#  'Alfred Hitchcock',
#  'Michael Curtiz',
#  'Charles Chaplin',
#  'Charles Chaplin',
#  'Thomas Kail',
#  'Todd Phillips',
#  'Bob Persichetti',
#  'Anthony Russo',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(dict([(k,pd.Series(v)) for k,v in cat.items() ]))

# %%
df.head(10)
# Out:
#                                            Title                            \
# 0                       The Shawshank Redemption  The Shawshank Redemption
# 1                                  The Godfather                     Drama
# 2                                The Dark Knight                     Drama
# 3  The Lord of the Rings: The Return of the King                       9.3
# 4                               Schindler's List                       9.3
# 5                          The Godfather Part II            Frank Darabont
# 6                                   12 Angry Men             The Godfather
# 7                                   Pulp Fiction              Crime, Drama
# 8             Kill Bill: The Whole Bloody Affair              Crime, Drama
# 9                                      Inception                       9.2
#
#                Director                      Genre Rating     Gross
# 0        Frank Darabont                      Drama    9.3   $28.34M
# ...

# %%
df.Title
# Out:
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                                    The Dark Knight
# 3      The Lord of the Rings: The Return of the King
# 4                                   Schindler's List
#                            ...
# 295                                              NaN
# 296                                              NaN
# 297                                              NaN
# 298                                              NaN
# 299                                              NaN
# Name: Title, Length: 300, dtype: object

# %%
df.columns
# Out:
# Index(['Title', '', 'Director', 'Genre', 'Rating', 'Gross'], dtype='object')

# %%
df.columns=['Title','empty','Director','Genre','Rating','Gross']

# %%
df=df.drop(['empty'],axis=1)

# %%
df.isnull().sum()
# Out:
# Title       250
# Director    250
# Genre       250
# Rating      250
# Gross       250
# dtype: int64

# %%
df.head(60)
# Out:
#                                                 Title              Director  \
# 0                            The Shawshank Redemption        Frank Darabont
# 1                                       The Godfather  Francis Ford Coppola
# 2                                     The Dark Knight     Christopher Nolan
# 3       The Lord of the Rings: The Return of the King         Peter Jackson
# 4                                    Schindler's List      Steven Spielberg
# 5                               The Godfather Part II  Francis Ford Coppola
# 6                                        12 Angry Men          Sidney Lumet
# 7                                        Pulp Fiction     Quentin Tarantino
# 8                  Kill Bill: The Whole Bloody Affair     Quentin Tarantino
# 9                                           Inception     Christopher Nolan
# 10              The Lord of the Rings: The Two Towers         Peter Jackson
# ...

# %%
df.shape
# Out:
# (300, 5)

# %%
df=df.dropna()

# %%
df
# Out:
#                                                 Title              Director  \
# 0                            The Shawshank Redemption        Frank Darabont
# 1                                       The Godfather  Francis Ford Coppola
# 2                                     The Dark Knight     Christopher Nolan
# 3       The Lord of the Rings: The Return of the King         Peter Jackson
# 4                                    Schindler's List      Steven Spielberg
# 5                               The Godfather Part II  Francis Ford Coppola
# 6                                        12 Angry Men          Sidney Lumet
# 7                                        Pulp Fiction     Quentin Tarantino
# 8                  Kill Bill: The Whole Bloody Affair     Quentin Tarantino
# 9                                           Inception     Christopher Nolan
# 10              The Lord of the Rings: The Two Towers         Peter Jackson
# ...

# %%
#Converted The Dataframe into csv file
df.to_csv('scrapped_imdb.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     50 non-null     object
#  1   Director  50 non-null     object
#  2   Genre     50 non-null     object
#  3   Rating    50 non-null     object
#  4   Gross     50 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %%
df['Rating']=df['Rating'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     50 non-null     object
#  1   Director  50 non-null     object
#  2   Genre     50 non-null     object
#  3   Rating    50 non-null     float64
#  4   Gross     50 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 2.3+ KB

# %%
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
plt.figure() #to plot the value counts as barplot
df.Genre.value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.xlabel('Genre',fontsize = 16)
plt.ylabel('Count',fontsize = 16)
plt.rcParams["figure.figsize"] = (18,12.5)

# %%
df["Gross"]= df["Gross"].str.replace('$','')
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9532/2127654157.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Gross"]= df["Gross"].str.replace('$','')

# %%
df.head(2)
# Out:
#                       Title              Director         Genre  Rating  \
# 0  The Shawshank Redemption        Frank Darabont         Drama     9.3
# 1             The Godfather  Francis Ford Coppola  Crime, Drama     9.2
#
#      Gross
# 0   28.34M
# 1  134.97M

# %%
df["Gross"]= df["Gross"].str.replace('M','')

# %%
df.head()
# Out:
#                                            Title              Director  \
# 0                       The Shawshank Redemption        Frank Darabont
# 1                                  The Godfather  Francis Ford Coppola
# 2                                The Dark Knight     Christopher Nolan
# 3  The Lord of the Rings: The Return of the King         Peter Jackson
# 4                               Schindler's List      Steven Spielberg
#
#                        Genre  Rating   Gross
# 0                      Drama     9.3   28.34
# 1               Crime, Drama     9.2  134.97
# 2       Action, Crime, Drama     9.0  534.86
# 3   Action, Adventure, Drama     9.0  377.85
# 4  Biography, Drama, History     9.0   96.90

# %%
df["Gross"]= df["Gross"].str.replace(',','.')

# %%
df['Gross']=df['Gross'].astype('float')

# %%
df.describe()
# Out:
#           Rating       Gross
# count  50.000000   50.000000
# mean    8.642000  177.632440
# std     0.220473  182.762385
# min     8.400000    0.020000
# 25%     8.500000   36.827500
# 50%     8.600000  131.560000
# 75%     8.800000  271.995000
# max     9.300000  858.370000

# %%
df.iloc[8]
# Out:
# Title       Kill Bill: The Whole Bloody Affair
# Director                     Quentin Tarantino
# Genre                  Action, Crime, Thriller
# Rating                                     8.8
# Gross                                   11.588
# Name: 8, dtype: object

# %%
df
# Out:
#                                                 Title              Director  \
# 0                            The Shawshank Redemption        Frank Darabont
# 1                                       The Godfather  Francis Ford Coppola
# 2                                     The Dark Knight     Christopher Nolan
# 3       The Lord of the Rings: The Return of the King         Peter Jackson
# 4                                    Schindler's List      Steven Spielberg
# 5                               The Godfather Part II  Francis Ford Coppola
# 6                                        12 Angry Men          Sidney Lumet
# 7                                        Pulp Fiction     Quentin Tarantino
# 8                  Kill Bill: The Whole Bloody Affair     Quentin Tarantino
# 9                                           Inception     Christopher Nolan
# 10              The Lord of the Rings: The Two Towers         Peter Jackson
# ...

# %%
plt.figure(figsize=(27,10))
sns.barplot('Director' ,'Gross', data=df ,palette='gist_rainbow_r')
plt.xlabel('Director', fontsize=35)
plt.xticks(rotation=90,fontsize=30)
plt.ylabel('Gross', fontsize=35)

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
sns.distplot(df['Gross'],color='darkred')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gross', ylabel='Density'>

# %%
sns.distplot(df['Rating'],color='darkred')
print("Highest percentage is:",df['Rating'].max(),"%")
sns.set(rc={'figure.figsize':(10,6)})
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Highest percentage is: 9.3 %

# %%
index=df['Genre'].value_counts().index
values=df['Genre'].value_counts()
plt.figure(figsize=(18,10))

plt.pie(values,labels=index,autopct="%1.1f%%",wedgeprops={'edgecolor':'black'},pctdistance=0.9)
plt.show()
print(df['Genre'].value_counts())
# Out:
# Action, Adventure, Drama        5
# Crime, Drama                    5
# Drama                           3
# Crime, Drama, Thriller          3
# Biography, Drama, History       2
# Action, Adventure, Sci-Fi       2
# Action, Sci-Fi                  2
# Action, Adventure, Fantasy      2
# Comedy, Drama, Romance          2
# Crime, Drama, Mystery           2
# Action, Crime, Drama            2
# Adventure, Comedy, Sci-Fi       1
# Animation, Adventure, Comedy    1
# Animation, Action, Adventure    1
# Drama, Romance, War             1
# Mystery, Thriller               1
# Horror, Mystery, Thriller       1
# Western                         1
# Horror, Sci-Fi                  1
# Drama, Mystery, War             1
# Drama, Music                    1
# Animation, Adventure, Drama     1
# Drama, Mystery, Sci-Fi          1
# Action, Crime, Thriller         1
# Drama, Family, Fantasy          1
# Crime, Drama, Fantasy           1
# Drama, War                      1
# ...

# %%
plt.figure(figsize=(27,10))
sns.barplot('Title' ,'Gross', data=df ,palette='gist_rainbow_r')
plt.xlabel('Title', fontsize=35)
plt.xticks(rotation=90,fontsize=30)
plt.ylabel('Gross', fontsize=35)

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(27,10))
sns.barplot('Title' ,'Rating', data=df ,palette='gist_rainbow_r')
plt.xlabel('Title', fontsize=35)
plt.xticks(rotation=90,fontsize=30)
plt.ylabel('Rating', fontsize=35)

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.scatter(x=df['Rating'],y=df['Gross'],color='#01153E')
plt.subplot().ticklabel_format(useOffset=False,style='plain')
plt.xlabel('Rating')
plt.ylabel("Collection")
plt.show()

# %%
df.corr()
# Out:
#           Rating     Gross
# Rating  1.000000 -0.060674
# Gross  -0.060674  1.000000

# %% [markdown]
# so the rating of the movie won't affect the Grosser

# %%
plt.figure(figsize=(27,10))
sns.barplot('Genre' ,'Rating', data=df ,palette='gist_rainbow_r')
plt.xlabel('Genre', fontsize=35)
plt.xticks(rotation=90,fontsize=30)
plt.ylabel('Rating', fontsize=35)

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(27,10))
sns.barplot('Genre' ,'Gross', data=df ,palette='gist_rainbow_r')
plt.xlabel('Genre', fontsize=35)
plt.xticks(rotation=90,fontsize=30)
plt.ylabel('Gross', fontsize=35)

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.
